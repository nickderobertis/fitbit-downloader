# %%
import os
os.chdir("..")

# %%
from fitbit import Fitbit
import datetime

CLIENT_ID = "23BM8T"
CLIENT_SECRET = "035847ddd8e6d089732f4a28fef08d98"
ACCESS_TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyM0JNOFQiLCJzdWIiOiI5TjNHVlAiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJhY3QgcnNldCBybG9jIHJ3ZWkgcmhyIHJudXQgcnBybyByc2xlIiwiZXhwIjoxNjM1NjI4ODIwLCJpYXQiOjE2MzU2MDAwMjB9.1P0xzsruxx-B_MFoAlgfCoSYr7216W__5NLSIFZw1ns"
REFRESH_TOKEN = "8f4e2664fe19a7594a8c5546686fe070d1671dbbfbaf940ad38dd46526d44dc1"

client = Fitbit(CLIENT_ID, CLIENT_SECRET, oauth2=True, access_token=ACCESS_TOKEN, refresh_token=REFRESH_TOKEN)

# %%
from fitbit_downloader.download_samples import download_sample_responses

# %%
download_sample_responses(client)

# %%
client.activities()
# Out:
# {'activities': [],
#  'goals': {'activeMinutes': 30,
#   'caloriesOut': 2993,
#   'distance': 5,
#   'floors': 10,
#   'steps': 10000},
#  'summary': {'activeScore': -1,
#   'activityCalories': 245,
#   'caloriesBMR': 720,
#   'caloriesOut': 928,
#   'distances': [{'activity': 'total', 'distance': 0.67},
#    {'activity': 'tracker', 'distance': 0.67},
#    {'activity': 'loggedActivities', 'distance': 0},
#    {'activity': 'veryActive', 'distance': 0},
#    {'activity': 'moderatelyActive', 'distance': 0},
#    {'activity': 'lightlyActive', 'distance': 0.64},
#    {'activity': 'sedentaryActive', 'distance': 0}],
#   'elevation': 30,
#   'fairlyActiveMinutes': 0,
#   'floors': 3,
#   'heartRateZones': [{'caloriesOut': 338.10854,
#     'max': 112,
#     'min': 30,
#     'minutes': 166,
#     'name': 'Out of Range'},
#    {'caloriesOut': 84.8141,
#     'max': 138,
#     'min': 112,
#     'minutes': 14,
#     'name': 'Fat Burn'},
#    {'caloriesOut': 11.73368,
#     'max': 171,
# ...

# %%
client.activity_detail("heart")
# Out:
# ---------------------------------------------------------------------------
# HTTPBadRequest                            Traceback (most recent call last)
# /tmp/ipykernel_1622908/939909612.py in <module>
# ----> 1 client.activity_detail("heart")
#
# ~/.local/share/virtualenvs/fitbit-downloader-nva461K0-python/lib/python3.10/site-packages/fitbit/api.py in activity_detail(self, activity_id)
#     838             activity_id=activity_id
#     839         )
# --> 840         return self.make_request(url)
#     841
#     842     def search_foods(self, query):
#
# ~/.local/share/virtualenvs/fitbit-downloader-nva461K0-python/lib/python3.10/site-packages/fitbit/api.py in make_request(self, *args, **kwargs)
#     254
#     255         method = kwargs.get('method', 'POST' if 'data' in kwargs else 'GET')
# --> 256         response = self.client.make_request(*args, **kwargs)
#     257
#     258         if response.status_code == 202:
#
# ...

# %%
client.activity_stats()
# Out:
# {'best': {'total': {'distance': {'date': '2021-10-30',
#     'value': 0.6428147118359201},
#    'floors': {'date': '2021-10-30', 'value': 3.00000000456},
#    'steps': {'date': '2021-10-30', 'value': 1405}},
#   'tracker': {'distance': {'date': '2021-10-30', 'value': 0.6428147118359201},
#    'floors': {'date': '2021-10-30', 'value': 3.00000000456},
#    'steps': {'date': '2021-10-30', 'value': 1405}}},
#  'lifetime': {'total': {'activeScore': -1,
#    'caloriesOut': -1,
#    'distance': 1.23,
#    'floors': 13,
#    'steps': 2779},
#   'tracker': {'activeScore': -1,
#    'caloriesOut': -1,
#    'distance': 1.23,
#    'floors': 13,
#    'steps': 2779}}}

# %%
client.get_devices()
# Out:
# [{'battery': 'High',
#   'batteryLevel': 90,
#   'deviceVersion': 'Charge 4',
#   'features': [],
#   'id': '1938169157',
#   'lastSyncTime': '2021-10-30T09:23:09.000',
#   'mac': 'B3E1998D91C8',
#   'type': 'TRACKER'}]

# %%
client.get_sleep(datetime.date.today())
# Out:
# {'sleep': [],
#  'summary': {'totalMinutesAsleep': 0,
#   'totalSleepRecords': 0,
#   'totalTimeInBed': 0}}

# %%
client.sleep()
# Out:
# {'sleep': [],
#  'summary': {'totalMinutesAsleep': 0,
#   'totalSleepRecords': 0,
#   'totalTimeInBed': 0}}

# %%
client.intraday_time_series("activities/floors")
# Out:
# {'activities-floors': [{'dateTime': '2021-10-30', 'value': '3'}],
#  'activities-floors-intraday': {'dataset': [{'time': '00:00:00', 'value': 0},
#    {'time': '00:01:00', 'value': 0},
#    {'time': '00:02:00', 'value': 0},
#    {'time': '00:03:00', 'value': 0},
#    {'time': '00:04:00', 'value': 0},
#    {'time': '00:05:00', 'value': 0},
#    {'time': '00:06:00', 'value': 0},
#    {'time': '00:07:00', 'value': 0},
#    {'time': '00:08:00', 'value': 0},
#    {'time': '00:09:00', 'value': 0},
#    {'time': '00:10:00', 'value': 0},
#    {'time': '00:11:00', 'value': 0},
#    {'time': '00:12:00', 'value': 0},
#    {'time': '00:13:00', 'value': 0},
#    {'time': '00:14:00', 'value': 0},
#    {'time': '00:15:00', 'value': 0},
#    {'time': '00:16:00', 'value': 0},
#    {'time': '00:17:00', 'value': 0},
#    {'time': '00:18:00', 'value': 0},
#    {'time': '00:19:00', 'value': 0},
#    {'time': '00:20:00', 'value': 0},
#    {'time': '00:21:00', 'value': 0},
# ...

# %%
client.intraday_time_series("activities/steps")
# Out:
# {'activities-steps': [{'dateTime': '2021-10-30', 'value': '1466'}],
#  'activities-steps-intraday': {'dataset': [{'time': '00:00:00', 'value': 0},
#    {'time': '00:01:00', 'value': 0},
#    {'time': '00:02:00', 'value': 0},
#    {'time': '00:03:00', 'value': 0},
#    {'time': '00:04:00', 'value': 0},
#    {'time': '00:05:00', 'value': 0},
#    {'time': '00:06:00', 'value': 0},
#    {'time': '00:07:00', 'value': 0},
#    {'time': '00:08:00', 'value': 0},
#    {'time': '00:09:00', 'value': 0},
#    {'time': '00:10:00', 'value': 0},
#    {'time': '00:11:00', 'value': 0},
#    {'time': '00:12:00', 'value': 0},
#    {'time': '00:13:00', 'value': 0},
#    {'time': '00:14:00', 'value': 0},
#    {'time': '00:15:00', 'value': 0},
#    {'time': '00:16:00', 'value': 0},
#    {'time': '00:17:00', 'value': 0},
#    {'time': '00:18:00', 'value': 0},
#    {'time': '00:19:00', 'value': 0},
#    {'time': '00:20:00', 'value': 0},
#    {'time': '00:21:00', 'value': 0},
# ...

# %%
client.intraday_time_series("activities/heart")
# Out:
# {'activities-heart': [{'dateTime': '2021-10-30',
#    'value': {'customHeartRateZones': [],
#     'heartRateZones': [{'caloriesOut': 888.3161,
#       'max': 112,
#       'min': 30,
#       'minutes': 1434,
#       'name': 'Out of Range'},
#      {'caloriesOut': 40.812799999999996,
#       'max': 138,
#       'min': 112,
#       'minutes': 5,
#       'name': 'Fat Burn'},
#      {'caloriesOut': 5.61176,
#       'max': 171,
#       'min': 138,
#       'minutes': 1,
#       'name': 'Cardio'},
#      {'caloriesOut': 0,
#       'max': 220,
#       'min': 171,
#       'minutes': 0,
#       'name': 'Peak'}]}}],
#  'activities-heart-intraday': {'dataset': [{'time': '06:08:00', 'value': 69},
#    {'time': '06:09:00', 'value': 70},
#    {'time': '06:10:00', 'value': 66},
#    {'time': '06:11:00', 'value': 63},
#    {'time': '06:12:00', 'value': 67},
#    {'time': '06:13:00', 'value': 68},
#    {'time': '06:23:00', 'value': 76},
#    {'time': '06:24:00', 'value': 72},
# ...

# %%
client.intraday_time_series("activities/elevation")
# Out:
# {'activities-elevation': [{'dateTime': '2021-10-30', 'value': '30'}],
#  'activities-elevation-intraday': {'dataset': [{'time': '00:00:00',
#     'value': 0},
#    {'time': '00:01:00', 'value': 0},
#    {'time': '00:02:00', 'value': 0},
#    {'time': '00:03:00', 'value': 0},
#    {'time': '00:04:00', 'value': 0},
#    {'time': '00:05:00', 'value': 0},
#    {'time': '00:06:00', 'value': 0},
#    {'time': '00:07:00', 'value': 0},
#    {'time': '00:08:00', 'value': 0},
#    {'time': '00:09:00', 'value': 0},
#    {'time': '00:10:00', 'value': 0},
#    {'time': '00:11:00', 'value': 0},
#    {'time': '00:12:00', 'value': 0},
#    {'time': '00:13:00', 'value': 0},
#    {'time': '00:14:00', 'value': 0},
#    {'time': '00:15:00', 'value': 0},
#    {'time': '00:16:00', 'value': 0},
#    {'time': '00:17:00', 'value': 0},
#    {'time': '00:18:00', 'value': 0},
#    {'time': '00:19:00', 'value': 0},
#    {'time': '00:20:00', 'value': 0},
#    {'time': '00:21:00', 'value': 0},
# ...
